# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('e:/gaji_guru_dunia.csv')
df
# Out:
#      LOCATION      INDICATOR       SUBJECT MEASURE FREQUENCY  TIME  \
# 0         HUN  TEACHERSALARY     PRY_START     USD         A  2020
# 1         IRL  TEACHERSALARY       PRY_TOP     USD         A  2020
# 2         NZL  TEACHERSALARY    PRY15YREXP     USD         A  2020
# 3         SWE  TEACHERSALARY    PRY15YREXP     USD         A  2020
# 4         SWE  TEACHERSALARY     PRY_START     USD         A  2020
# ...       ...            ...           ...     ...       ...   ...
# 1450      SAU  TEACHERSALARY  LOWSRY_START     USD         A  2020
# 1451      SAU  TEACHERSALARY  UPPSRY_START     USD         A  2020
# 1452      ZAF  TEACHERSALARY     PRY_START     USD         A  2019
# 1453      ZAF  TEACHERSALARY  LOWSRY_START     USD         A  2019
# 1454      ZAF  TEACHERSALARY  UPPSRY_START     USD         A  2019
#
#              Value  Flag Codes
# 0     15812.869234         NaN
# 1     71821.518347         NaN
# 2     53246.838228         NaN
# 3     49231.836673         NaN
# ...

# %%
df['Value'].max()
# Out:
# 117579.542219611

# %%
df.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
df.sort_values('Value', ascending=False)[['LOCATION','Value']].head(50)
# Out:
#      LOCATION          Value
# 25        CHE  117579.542220
# 9         LUX  109203.910140
# 31        CHE  103951.520584
# 7         CHE   92670.547120
# 24        CHE   76392.632389
# 1         IRL   71821.518347
# 29        CAN   71663.568700
# 23        CHE   67837.263251
# 6         CHE   60947.541202
# 22        SWE   59052.695284
# 30        SWE   58287.433574
# 1454      ZAF   57893.264307
# 1453      ZAF   57893.264307
# 1452      ZAF   57893.264307
# 5         SWE   56756.910154
# 1451      SAU   54546.420539
# 18        ITA   54270.540965
# 2         NZL   53246.838228
# 12        SWE   50889.903711
# 11        SWE   50686.471640
# 1450      SAU   49941.852571
# 1449      SAU   49941.852571
# 28        COL   49534.375537
# 16        COL   49534.375537
# 32        COL   49534.375537
# 3         SWE   49231.836673
# 21        SWE   44257.635558
# 35        SVN   44203.101330
# 20        SWE   44002.548321
# 14        COL   43073.406850
# 17        COL   43073.406850
# ...

# %%
df[df['LOCATION'].str.contains('IN')]
# Out:
#     LOCATION      INDICATOR         SUBJECT  MEASURE FREQUENCY  TIME  \
# 186      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2000
# 187      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2005
# 188      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2006
# 189      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2007
# 190      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2008
# 191      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2009
# 192      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2010
# 193      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2011
# 194      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2012
# 195      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2013
# 196      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2014
# 197      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2015
# 198      FIN  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2016
# ...

# %%
df_i = df.groupby('LOCATION')['LOCATION'].value_counts()
df_i
# Out:
# LOCATION  LOCATION
# AUS       AUS         45
# AUT       AUT         51
# BRA       BRA          4
# CAN       CAN         25
# CHE       CHE          6
# CHL       CHL         42
# COL       COL         30
# CRI       CRI         15
# CZE       CZE         24
# DEU       DEU         48
# DNK       DNK         51
# ESP       ESP         48
# FIN       FIN         51
# FRA       FRA         51
# GRC       GRC         52
# HUN       HUN         52
# IRL       IRL         52
# ISR       ISR         52
# ITA       ITA         52
# JPN       JPN         51
# KOR       KOR         48
# LTU       LTU         18
# LUX       LUX         50
# LVA       LVA         27
# MEX       MEX         41
# NLD       NLD         24
# NOR       NOR         48
# NZL       NZL         20
# OAVG      OAVG        48
# POL       POL         42
# PRT       PRT         48
# SAU       SAU          3
# SVK       SVK         37
# SVN       SVN         52
# SWE       SWE         42
# TUR       TUR         51
# ...

# %%
df['SUBJECT'].unique()
# Out:
# array(['PRY_START', 'PRY_TOP', 'PRY15YREXP', 'UPPSRY_15YREXP',
#        'LOWSRY_15YREXP', 'UPPSRY_TOP', 'UPPSRY_START', 'LOWSRY_START',
#        'LOWSRY_TOP', 'EARLYCHILDEDU_TOP', 'EARLYCHILDEDU_START',
#        'EARLYCHILDEDU_15YREXP'], dtype=object)

# %%
df
# Out:
#      LOCATION      INDICATOR       SUBJECT MEASURE FREQUENCY  TIME  \
# 0         HUN  TEACHERSALARY     PRY_START     USD         A  2020
# 1         IRL  TEACHERSALARY       PRY_TOP     USD         A  2020
# 2         NZL  TEACHERSALARY    PRY15YREXP     USD         A  2020
# 3         SWE  TEACHERSALARY    PRY15YREXP     USD         A  2020
# 4         SWE  TEACHERSALARY     PRY_START     USD         A  2020
# ...       ...            ...           ...     ...       ...   ...
# 1450      SAU  TEACHERSALARY  LOWSRY_START     USD         A  2020
# 1451      SAU  TEACHERSALARY  UPPSRY_START     USD         A  2020
# 1452      ZAF  TEACHERSALARY     PRY_START     USD         A  2019
# 1453      ZAF  TEACHERSALARY  LOWSRY_START     USD         A  2019
# 1454      ZAF  TEACHERSALARY  UPPSRY_START     USD         A  2019
#
#              Value  Flag Codes
# 0     15812.869234         NaN
# 1     71821.518347         NaN
# 2     53246.838228         NaN
# 3     49231.836673         NaN
# ...

# %%
round(df['Value'].mean())
# Out:
# 1643

# %%
df[df['Value']<1643].sort_values('Value', ascending=False).head(20)
# Out:
#      LOCATION      INDICATOR         SUBJECT  MEASURE FREQUENCY  TIME  \
# 1448      LTU  TEACHERSALARY  UPPSRY_15YREXP  IDX2010         A  2020
# 1442      LTU  TEACHERSALARY      PRY15YREXP  IDX2010         A  2020
# 1436      LTU  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2020
# 1441      LTU  TEACHERSALARY      PRY15YREXP  IDX2010         A  2019
# 1447      LTU  TEACHERSALARY  UPPSRY_15YREXP  IDX2010         A  2019
# 1435      LTU  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2019
# 376       GRC  TEACHERSALARY  UPPSRY_15YREXP  IDX2010         A  2010
# 359       GRC  TEACHERSALARY      PRY15YREXP  IDX2010         A  2010
# 342       GRC  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2010
# 372       GRC  TEACHERSALARY  UPPSRY_15YREXP  IDX2010         A  2006
# 355       GRC  TEACHERSALARY      PRY15YREXP  IDX2010         A  2006
# 338       GRC  TEACHERSALARY  LOWSRY_15YREXP  IDX2010         A  2006
# ...
